# %% [markdown]
# # WebBasedLoaders

# %%
from langchain_community.document_loaders import WebBaseLoader
import textwrap

# %%
urls = [
'https://www.ft.com/crypto',
'https://www.ft.com/ft-trading-room',
'https://www.livemint.com/money',
'https://www.livemint.com/market'
    ]

# %%
loader = WebBaseLoader(urls)

# %%
loader

# %%
docs = []
async for doc in loader.alazy_load():
    docs.append(doc)

# %%
len(docs)
# Out:
# 4

# %%
def format_docs(docs):
    return "\n\n".join([x.page_content for x in docs])

# %%
context = format_docs(docs)
len(context)
# Out:
# 54826

# %%
import re

def text_clean(text):
    text = re.sub(r'\n\n', '\n', text)
    text = re.sub(r'\t+', '\t', text)
    text = re.sub(r'\s+', ' ', text)
    return text

# %%
context = text_clean(context)
len(context)
# Out:
# 52080

# %%
textwrap.wrap(context)
# Out:
# ['CryptofinanceAccessibility helpSkip to navigationSkip to contentSkip',
#  'to footerSign InSubscribeOpen side navigation menuOpen search',
#  'barFinancial TimesSubscribeSign InSearch the FTSearchClose search',
#  'barCloseHomeWorldSectionsWorld HomeMiddle East warGlobal',
#  'EconomyUKUSChinaAfricaAsia PacificEmerging MarketsEuropeWar in',
#  'UkraineAmericasMiddle East & North AfricaMost ReadTrump tells Vance to',
#  'shore up support for Gaetz as misconduct allegations swirlChinese',
#  'vessel spotted where Baltic Sea cables were severedUkraine strikes',
#  'Russia with US-made long-range missiles for first timeTrump picks',
#  'Howard Lutnick to run commerce departmentTrump’s demolition of the US',
#  'stateUSSectionsUS HomeUS EconomyInvesting in AmericaUS CompaniesUS',
#  'Politics & PolicyUS Presidential Election 2024Most ReadTrump tells',
#  'Vance to shore up support for Gaetz as misconduct allegations',
#  'swirlTrump picks Howard Lutnick to run commerce departmentTrump’s',
#  'demolition of the US stateWhy Trump’s trade war will cause chaos UK',
#  'should use Farage as ‘bridgehead’ to Trump and Musk, says Mandelson',
#  'CompaniesSectionsCompanies',
#  'HomeEnergyFinancialsHealthIndustrialsMediaProfessional ServicesRetail',
#  '& ConsumerTech SectorTelecomsTransportMost ReadChinese vessel spotted',
#  'where Baltic Sea cables were severedBridgewater opens strategy to',
#  'retail investors through State Street ETFCorporate insiders cash in on',
#  'post-election US stock market surgeThousands of farmers protest in',
#  'London against tax changesHead of Volkswagen’s North American division',
#  'steps downTechSectionsTech HomeArtificial',
#  'intelligenceSemiconductorsCyber SecuritySocial MediaMost ReadAI can',
#  'learn to think before it speaks UK will fall behind supercomputer',
#  'rivals, head of axed £800mn project warns BA flights hit by fresh',
#  'round of IT problemsChinese tech groups build AI teams in Silicon',
#  'ValleyCisco swims against Big Tech tide to set standard in workplace',
#  'equality MarketsSectionsMarkets HomeAlphavilleMarkets',
#  'DataCryptoCapital MarketsCommoditiesCurrenciesEquitiesWealth',
#  'ManagementMoral MoneyETF HubFund ManagementTradingMost ReadBridgewater',
#  'opens strategy to retail investors through State Street ETFCorporate',
#  'insiders cash in on post-election US stock market surgeEuropean stocks',
#  'fall as Ukraine war escalation unsettles marketsHow to deal with noisy',
#  'marketsSwiss prosecutors accuse Trafigura of paying €5mn in bribes to',
#  'Angolan official ClimateOpinionSectionsOpinion HomeColumnistsThe FT',
#  'ViewThe Big ReadLexObituariesLettersMost ReadTrump’s demolition of the',
#  'US stateWhy Trump’s trade war will cause chaos AI can learn to think',
#  'before it speaks Britain needs a coherent China strategyLet’s get real',
#  'about what Labour reforms mean for employersLexWork &',
#  'CareersSectionsWork & Careers HomeBusiness School RankingsBusiness',
#  "EducationEurope's Start-Up HubsEntrepreneurshipRecruitmentBusiness",
#  'BooksBusiness TravelWorking ItMost ReadBest books of 2024:',
#  'BusinessLet’s get real about what Labour reforms mean for',
#  'employersStealth sackings: why do employers fire staff for minor',
#  'misdemeanours?Cisco swims against Big Tech tide to set standard in',
#  'workplace equality No work phone? Companies tell staff to bring their',
#  'ownLife & ArtsSectionsLife & Arts HomeArtsBooksFood & DrinkFT',
#  'MagazineHouse & HomeStyleTravelFT GlobetrotterMost ReadBest books of',
#  '2024: BusinessBest books of 2024: Environment, Science and',
#  'TechnologyHot property: five brownstone homesBest books of 2024:',
#  'Literary non-fictionBest books of 2024: Crime and',
#  'ThrillersHTSIMarketsCryptoDigital Assets DashboardMenuSearchHomeWorldU',
#  'SCompaniesTechMarketsClimateOpinionLexWork & CareersLife &',
#  'ArtsHTSIFinancial TimesSubscribeSign InSearch the FTSearchClose search',
#  'barClose Crypto Add to myFT Exchange traded fundsTrump victory tipped',
#  'to break logjam of exotic US crypto ETF filings SEC has only allowed',
#  'spot bitcoin and ether ETFs, while Europe has ETPs invested in about',
#  '30 cryptocurrenciesPolitical risk and investmentBitcoin, dollar and',
#  'Tesla jump as investors pile into ‘Trump trades’FTX Trading LtdFTX',
#  'sues Binance and former chief Zhao for $1.8bnFTX Trading LtdSam',
#  'Trabucco is probably just in San FranciscoBitcoinExamining',
#  'MicroStrategy’s record-shattering $21bn ATM Opinion & AnalysisStephen',
#  'DiehlBitcoin’s shift towards respectability should concern us allKatie',
#  'MartinBitcoin’s big bang moment is impossible to',
#  'ignoreLexCryptocurrenciesTrump talk is enough to fire up a crypto boom',
#  'Premium contentLexBitcoinMeme coins’ unlikely rally turns gags into',
#  'riches Premium contentResources & ExplainersDigital assets dashboard,',
#  'real-time data and insight at a glanceFT GuidesHow safe are digital',
#  'assets?The FT crypto glossaryBehind the Money podcastBonus: Michael',
#  'Lewis on FTX & Sam Bankman-FriedCryptocurrenciesFTX: the legend of Sam',
#  'Bankman-Fried | FT Film Promoted Content More Cryptofinance Monday, 18',
#  'November, 2024 Trump Media & Technology GroupTrump’s social media',
#  'group in talks to buy crypto trading venueTruth Social owner is close',
#  'to an all-share takeover of Intercontinental Exchange’s Bakkt Save',
#  'Friday, 15 November, 2024 FT News Briefing podcast12 min',
#  'listenCrypto’s Trump cardPresident-elect Donald Trump’s pro-crypto',
#  'rhetoric has sent bitcoin soaring Save Monday, 11 November, 2024 FT',
#  'News Briefing podcast11 min listenChina’s $1.4tn fiscal package fails',
#  'to exciteBeijing unveils fiscal stimulus to help shore up its',
#  'faltering economy Save Saturday, 9 November, 2024',
#  'CryptocurrenciesBinance boss hails crypto ‘golden age’ as Trump win',
#  'fires up industryExecutives expects radical shift in regulatory',
#  'approach in Washington after Democrat defeat Save Wednesday, 6',
#  'November, 2024 BitcoinBitcoin hits record above $75,000 as crypto',
#  'industry celebrates Trump winRepublican presidential victor has vowed',
#  'to end regulatory crackdown on cryptocurrency industry Save Wednesday,',
#  '6 November, 2024 Futures contractsCME customers criticise futures',
#  'exchange after it wins approval to also act as brokerDerivatives',
#  'traders warn of potential ‘conflicts of interest’ as Chicago group',
#  'gains licence Save Friday, 1 November, 2024 ESG investingTrump-aligned',
#  'fund manager Strive jumps into bitcoinWealth group doubles down on',
#  'themes foremost in the ex-president’s financial community as election',
#  'day nears Save Thursday, 31 October, 2024 Bitcoin‘Satoshi Nakamoto’',
#  'says he also designed the Twitter logoAn FTAV frontline dispatch from',
#  '‘a historic event in the cryptocurrency landscape’ Save Monday, 28',
#  'October, 2024 CryptocurrenciesCrypto exchanges turn to derivatives to',
#  'lure cautious investorsNew market entrants switch focus to offering',
#  'leveraged bets Save Wednesday, 23 October, 2024',
#  'CryptocurrenciesNigeria drops money laundering charges against',
#  'detained Binance executiveUS citizen who heads financial crime',
#  'compliance at crypto exchange had been held since February Save',
#  'Wednesday, 23 October, 2024 Special ReportInvesting in ArgentinaThe',
#  'hidden billions Argentines hold outside their financial systemDecades',
#  'of distrust of the country’s currency has resulted in a ‘dollars under',
#  'the mattress’ culture Save Wednesday, 23 October, 2024 Exchange traded',
#  'fundsJapan maintains cautious stance on crypto ETFsTax and regulatory',
#  'restrictions continue to loom large even as firms make preparations to',
#  'launch digital asset products Save Friday, 18 October, 2024 House &',
#  'HomeCrypto has designs on real estate Buying blockchain-listed',
#  '‘slices’ of properties is a nascent, niche and troubled market. Can it',
#  'find its feet beyond the crypto crowd? Save Thursday, 17 October, 2024',
#  'CryptocurrenciesDonald Trump has a new crypto venture. The industry is',
#  'not impressedIndustry executives worry World Liberty Financial will',
#  'undermine painstaking efforts to rebuild trust after scandals Save',
#  'Wednesday, 16 October, 2024 EU financial regulationEU markets watchdog',
#  'pushes for extra cyber defences in new crypto rulesEsma asks for',
#  'amendment to tighten regulation with demand for external audits of',
#  'defences against hackers Save Wednesday, 9 October, 2024',
#  'CryptocurrenciesFBI creates its own crypto token to nab suspects in',
#  'alleged fraud schemeSting operation has already led to three arrests',
#  'for ‘on-demand market manipulation’ on trading platforms Save Tuesday,',
#  '8 October, 2024 Crypto.comCrypto.com sues SEC after receiving legal',
#  'threat from US regulatorCrypto exchange accuses securities watchdog of',
#  '‘over-reach’ and argues it ‘cannot lawfully regulate’ token sales Save',
#  'Tuesday, 8 October, 2024 Grayscale Ethereum Trust (ETH)Can a crypto',
#  'ETF die of apathy?Forever and ether, amen Save Friday, 4 October, 2024',
#  'Exchange traded fundsActive ETFs triumph over passives in fees from',
#  'new flows Record 70% income haul from fresh money is shot in the arm',
#  'for active fund industry Save Wednesday, 2 October, 2024 Digital',
#  'economyUK’s City minister pushes for blockchain gilts despite concerns',
#  'Treasury unit has raised questions over new technology Save Wednesday,',
#  '2 October, 2024 Exchange traded funds21Shares slashes fees on two',
#  'flagship crypto ETPsFee cuts are latest in price war that started with',
#  'approval of spot bitcoin ETFs in US in January Save Tuesday, 24',
#  'September, 2024 Caroline EllisonCaroline Ellison gets 2-year prison',
#  'sentence for FTX fraudSam Bankman-Fried’s former associate and',
#  'girlfriend had co-operated with prosecutors since pleading guilty Save',
#  'Friday, 20 September, 2024 Decentralised financeEthereum co-founder',
#  'says partisanship will block Trump crypto plansCharles Hoskinson warns',
#  'the former president’s proposed new digital assets platform could',
#  'politicise the industry Save Thursday, 19 September, 2024 FintechSpeak',
#  'your brains: CBDC editionSolution (M, 16) seeks problem Save',
#  'Wednesday, 18 September, 2024 CryptocurrenciesSwitzerland’s SIX',
#  'explores launching crypto exchangeStock exchange operator says digital',
#  'coins becoming ‘recognised asset class’ Save Previous page You are on',
#  'page 1 Next page Most Read Bitcoin’s shift towards respectability',
#  'should concern us all Trump’s social media group in talks to buy',
#  'crypto trading venue Bitcoin’s big bang moment is impossible to ignore',
#  'Examining MicroStrategy’s record-shattering $21bn ATM Trump victory',
#  'tipped to break logjam of exotic US crypto ETF filings Join us at an',
#  'FT Live event Discover unmissable flagship events and members only',
#  'communities to expand your thinking and elevate your career FT',
#  'LiveCrypto and Digital Assets Summit AsiaTransforming mainstream',
#  'finance Thursday, 5 DecemberSingapore FT LiveNew Crypto Regulations:',
#  'Building a Better Financial System Opportunities and implications of',
#  'new regulations for crypto assets Wednesday, 11 DecemberOnline FT',
#  'LiveDigital Assets SummitThe next wave of institutional adoption',
#  'Tuesday, 6 May 2025London, UK Explore all events Useful',
#  'linksSupportView Site TipsHelp CentreContact UsAbout',
#  'UsAccessibilitymyFT TourCareersSuppliersLegal & PrivacyTerms &',
#  'ConditionsPrivacy PolicyCookie PolicyManage CookiesCopyrightSlavery',
#  'Statement & PoliciesServicesShare News Tips SecurelyIndividual',
#  'SubscriptionsProfessional SubscriptionsRepublishingExecutive Job',
#  'SearchAdvertise with the FTFollow the FT on XFT ChannelsFT',
#  'SchoolsToolsPortfolioFT AppFT Digital EditionFT EditAlerts HubBusiness',
#  'School RankingsSubscription ManagerNews feedNewslettersCurrency',
#  'ConverterCommunity & EventsFT Live EventsFT ForumsBoard Director',
#  'ProgrammeMore from the FT GroupMarkets data delayed by at least 15',
#  'minutes. © THE FINANCIAL TIMES LTD 2024. FT and ‘Financial Times’ are',
#  'trademarks of The Financial Times Ltd.The Financial Times and its',
#  'journalism are subject to a self-regulation regime under the FT',
#  'Editorial Code of Practice.Close side navigation',
#  'menuEdition:InternationalUKSearch the FTSearchSubscribe for full',
#  'accessTop sectionsHomeWorldShow more WorldMiddle East warGlobal',
#  'EconomyUKUSChinaAfricaAsia PacificEmerging MarketsEuropeWar in',
#  'UkraineAmericasMiddle East & North AfricaUSShow more USUS',
#  'EconomyInvesting in AmericaUS CompaniesUS Politics & PolicyUS',
#  'Presidential Election 2024CompaniesShow more',
#  'CompaniesEnergyFinancialsHealthIndustrialsMediaProfessional',
#  'ServicesRetail & ConsumerTech SectorTelecomsTransportTechShow more',
#  'TechArtificial intelligenceSemiconductorsCyber SecuritySocial',
#  'MediaMarketsShow more MarketsAlphavilleMarkets DataCryptoCapital',
#  'MarketsCommoditiesCurrenciesEquitiesWealth ManagementMoral MoneyETF',
#  'HubFund ManagementTradingClimateOpinionShow more OpinionColumnistsThe',
#  'FT ViewThe Big ReadLexObituariesLettersLexWork & CareersShow more Work',
#  "& CareersBusiness School RankingsBusiness EducationEurope's Start-Up",
#  'HubsEntrepreneurshipRecruitmentBusiness BooksBusiness TravelWorking',
#  'ItLife & ArtsShow more Life & ArtsArtsBooksFood & DrinkFT',
#  'MagazineHouse & HomeStyleTravelFT GlobetrotterPersonal FinanceShow',
#  'more Personal FinanceProperty & MortgagesInvestmentsPensionsTaxBanking',
#  '& SavingsAdvice & CommentNext ActHTSISpecial ReportsFT',
#  'recommendsAlphavilleFT EditLunch with the FTFT',
#  'Globetrotter#techAsiaMoral MoneyVisual and data',
#  'journalismNewslettersVideoPodcastsNews feedFT SchoolsFT Live EventsFT',
#  'ForumsBoard Director ProgrammemyFTPortfolioFT Digital',
#  'EditionCrosswordOur AppsHelp CentreSubscribeSign In FT Trading',
#  'RoomAccessibility helpSkip to navigationSkip to contentSkip to',
#  'footerSign InSubscribeOpen side navigation menuOpen search',
#  'barFinancial TimesSubscribeSign InSearch the FTSearchClose search',
#  'barCloseHomeWorldSectionsWorld HomeMiddle East warGlobal',
#  'EconomyUKUSChinaAfricaAsia PacificEmerging MarketsEuropeWar in',
#  'UkraineAmericasMiddle East & North AfricaMost ReadTrump tells Vance to',
#  'shore up support for Gaetz as misconduct allegations swirlChinese',
#  'vessel spotted where Baltic Sea cables were severedUkraine strikes',
#  'Russia with US-made long-range missiles for first timeTrump picks',
#  'Howard Lutnick to run commerce departmentTrump’s demolition of the US',
#  'stateUSSectionsUS HomeUS EconomyInvesting in AmericaUS CompaniesUS',
#  'Politics & PolicyUS Presidential Election 2024Most ReadTrump tells',
#  'Vance to shore up support for Gaetz as misconduct allegations',
#  'swirlTrump picks Howard Lutnick to run commerce departmentTrump’s',
#  'demolition of the US stateWhy Trump’s trade war will cause chaos UK',
#  'should use Farage as ‘bridgehead’ to Trump and Musk, says Mandelson',
#  'CompaniesSectionsCompanies',
#  'HomeEnergyFinancialsHealthIndustrialsMediaProfessional ServicesRetail',
#  '& ConsumerTech SectorTelecomsTransportMost ReadChinese vessel spotted',
#  'where Baltic Sea cables were severedBridgewater opens strategy to',
#  'retail investors through State Street ETFCorporate insiders cash in on',
#  'post-election US stock market surgeThousands of farmers protest in',
#  'London against tax changesHead of Volkswagen’s North American division',
#  'steps downTechSectionsTech HomeArtificial',
#  'intelligenceSemiconductorsCyber SecuritySocial MediaMost ReadAI can',
#  'learn to think before it speaks UK will fall behind supercomputer',
#  'rivals, head of axed £800mn project warns BA flights hit by fresh',
#  'round of IT problemsChinese tech groups build AI teams in Silicon',
#  'ValleyCisco swims against Big Tech tide to set standard in workplace',
#  'equality MarketsSectionsMarkets HomeAlphavilleMarkets',
#  'DataCryptoCapital MarketsCommoditiesCurrenciesEquitiesWealth',
#  'ManagementMoral MoneyETF HubFund ManagementTradingMost ReadBridgewater',
#  'opens strategy to retail investors through State Street ETFCorporate',
#  'insiders cash in on post-election US stock market surgeEuropean stocks',
#  'fall as Ukraine war escalation unsettles marketsHow to deal with noisy',
#  'marketsSwiss prosecutors accuse Trafigura of paying €5mn in bribes to',
#  'Angolan official ClimateOpinionSectionsOpinion HomeColumnistsThe FT',
#  'ViewThe Big ReadLexObituariesLettersMost ReadTrump’s demolition of the',
#  'US stateWhy Trump’s trade war will cause chaos AI can learn to think',
#  'before it speaks Britain needs a coherent China strategyLet’s get real',
#  'about what Labour reforms mean for employersLexWork &',
#  'CareersSectionsWork & Careers HomeBusiness School RankingsBusiness',
#  "EducationEurope's Start-Up HubsEntrepreneurshipRecruitmentBusiness",
#  'BooksBusiness TravelWorking ItMost ReadBest books of 2024:',
#  'BusinessLet’s get real about what Labour reforms mean for',
#  'employersStealth sackings: why do employers fire staff for minor',
#  'misdemeanours?Cisco swims against Big Tech tide to set standard in',
#  'workplace equality No work phone? Companies tell staff to bring their',
#  'ownLife & ArtsSectionsLife & Arts HomeArtsBooksFood & DrinkFT',
#  'MagazineHouse & HomeStyleTravelFT GlobetrotterMost ReadBest books of',
#  '2024: BusinessBest books of 2024: Environment, Science and',
#  'TechnologyHot property: five brownstone homesBest books of 2024:',
#  'Literary non-fictionBest books of 2024: Crime and',
#  'ThrillersHTSIMarketsTradingClearing & SettlementHigh Frequency',
#  'TradingMarkets RegulationOTC marketsDerivativesMenuSearchHomeWorldUSCo',
#  'mpaniesTechMarketsClimateOpinionLexWork & CareersLife &',
#  'ArtsHTSIFinancial TimesSubscribeSign InSearch the FTSearchClose search',
#  'barClose FT Trading Room Add to myFT Monday, 18 November, 2024',
#  'Clearing & SettlementEU regulator proposes shortening trade settlement',
#  'times from October 2027Esma recommendation will align bloc’s move with',
#  'UK plans Save Monday, 18 November, 2024 Inside BusinessPatrick',
#  'JenkinsThe yawning investability gap between US banks and UK',
#  'peersBritish lenders face a competitive threat from Trump’s plans for',
#  'regulatory bonfires Save Sunday, 17 November, 2024 The FT ViewThe',
#  'editorial boardThe new titans of Wall Street The rise of innovative',
#  'traders increases competition for banks — and work for authorities',
#  'Save Friday, 15 November, 2024 On Wall StreetJennifer HughesKilling',
#  'the CAT: why a key regulatory tool is under attack from Wall StreetKen',
#  'Griffin’s Citadel Securities is among those challenging the US market',
#  'surveillance system Save Friday, 15 November, 2024 H2O Asset',
#  'ManagementH2O investors file legal challenge to €250mn FCA',
#  'settlementGroup of 10,000 stakeholders applies for judicial review of',
#  'compensation deal approved by regulator Save Friday, 15 November, 2024',
#  'Exchange traded fundsTrump victory tipped to break logjam of exotic US',
#  'crypto ETF filings SEC has only allowed spot bitcoin and ether ETFs,',
#  'while Europe has ETPs invested in about 30 cryptocurrencies Save',
#  'Thursday, 14 November, 2024 AccountancyEx-BDO auditor banned for 20',
#  'years for faking signatures and documentsUK watchdog said Amanda',
#  'Nightingale had ‘acted with sustained dishonesty’ in her role as',
#  'senior manager Save Thursday, 14 November, 2024 FinancialsEndgame for',
#  'Endgame?Trump vs Basel III Save Monday, 11 November, 2024 New titans',
#  'of Wall Street — an FT seriesIs Chicago’s Don Wilson the smartest man',
#  'in trading?From cleaning up after Lehman Brothers to early bets on',
#  'Bitcoin, DRW has become an industry colossus Save Saturday, 9',
#  'November, 2024 CryptocurrenciesBinance boss hails crypto ‘golden age’',
#  'as Trump win fires up industryExecutives expects radical shift in',
#  'regulatory approach in Washington after Democrat defeat Save Friday, 8',
#  'November, 2024 Bank for International SettlementsSpanish central',
#  'banker set to inherit big challenges as next BIS head Pablo Hernández',
#  'de Cos to take over amid fears Donald Trump will derail progress on',
#  'setting capital standards for world’s biggest lenders Save Thursday, 7',
#  'November, 2024 UnhedgedMore capital is not the answer Premium',
#  'contentAn interview with Yale’s Steven Kelly Save Wednesday, 6',
#  'November, 2024 Futures contractsCME customers criticise futures',
#  'exchange after it wins approval to also act as brokerDerivatives',
#  'traders warn of potential ‘conflicts of interest’ as Chicago group',
#  'gains licence Save Friday, 1 November, 2024 Exchange traded fundsLow-',
#  'volatility ETFs lose favour as investors jump to buffered peersDespite',
#  'poor returns in recent years, analysts say people could be missing out',
#  'on their long-term investment potential Save Thursday, 31 October,',
#  '2024 Financial & markets regulationHong Kong cracks down on how banks',
#  'and hedge funds discuss block tradesRegulator brings in new measures',
#  'after launching criminal insider dealing case against Segantii Capital',
#  'Management Save Wednesday, 30 October, 2024 Brooke MastersThe',
#  'cautionary tale of Goldman and Apple’s credit cardRetail banking is',
#  'not only harder than it looks but also heavily regulated by watchdogs',
#  'who take their duties very seriously Save Wednesday, 30 October, 2024',
#  'Behind the Money podcast20 min listenUS election betting is on a',
#  'rollIn the months leading up to election day, people from around the',
#  'world have placed millions of dollars in wagers on who will be the',
#  'next American president Save Monday, 28 October, 2024 High frequency',
#  'tradingJump Trading, Virtu and the ‘hidden optical fibre cable’ under',
#  'an Ohio fieldSkywave Networks accuses Wall Street titans of',
#  '‘continuous racketeering and conspiracy’ Save Monday, 28 October, 2024',
#  'CryptocurrenciesCrypto exchanges turn to derivatives to lure cautious',
#  'investorsNew market entrants switch focus to offering leveraged bets',
#  'Save Wednesday, 23 October, 2024 Sergio ErmottiPolicymakers should not',
#  'exacerbate the risks of deglobalisationA fragmented approach to',
#  'rulemaking in banking around the world has the potential to be',
#  'destructive Save Tuesday, 22 October, 2024 Financial & markets',
#  'regulationIMF warns of ‘round-tripping’ fearsTechnique to shift risk',
#  'to investors may have ‘system-wide’ impact, fund warns Save Monday, 21',
#  'October, 2024 New titans of Wall Street — an FT seriesHow',
#  'Susquehanna’s Jeff Yass mastered the options gameObsession with odds',
#  'spawned a trading giant — and shaped the industry’s approach to',
#  'markets Save Friday, 18 October, 2024 Markets InsightEric PanEU',
#  'markets need to commit to catch up with US on T+1Adoption of new',
#  'settlement cycle has led to greater efficiency, increased liquidity',
#  'and enhanced risk mitigation Save Wednesday, 16 October, 2024 High',
#  'frequency tradingThe ‘mundane economics’ of trading at the speed of',
#  'lightProfessor Donald MacKenzie talks high-frequency trading Save',
#  'Wednesday, 16 October, 2024 EU financial regulationEU markets watchdog',
#  'pushes for extra cyber defences in new crypto rulesEsma asks for',
#  'amendment to tighten regulation with demand for external audits of',
#  'defences against hackers Save Previous page You are on page 1 Next',
#  'page Most Read The yawning investability gap between US banks and UK',
#  'peers The new titans of Wall Street EU regulator proposes shortening',
#  'trade settlement times from October 2027 Killing the CAT: why a key',
#  'regulatory tool is under attack from Wall Street Ex-BDO auditor banned',
#  'for 20 years for faking signatures and documents Join us at an FT Live',
#  'event Discover unmissable flagship events and members only communities',
#  'to expand your thinking and elevate your career FT LiveFuture of Asset',
#  'Management North AmericaReimagining fund management for the future',
#  'Tuesday, 7 October 202530 Hudson Yards, New York, NY, USA Explore all',
#  'events Useful linksSupportView Site TipsHelp CentreContact UsAbout',
#  'UsAccessibilitymyFT TourCareersSuppliersLegal & PrivacyTerms &',
#  'ConditionsPrivacy PolicyCookie PolicyManage CookiesCopyrightSlavery',
#  'Statement & PoliciesServicesShare News Tips SecurelyIndividual',
#  'SubscriptionsProfessional SubscriptionsRepublishingExecutive Job',
#  'SearchAdvertise with the FTFollow the FT on XFT ChannelsFT',
#  'SchoolsToolsPortfolioFT AppFT Digital EditionFT EditAlerts HubBusiness',
#  'School RankingsSubscription ManagerNews feedNewslettersCurrency',
#  'ConverterCommunity & EventsFT Live EventsFT ForumsBoard Director',
#  'ProgrammeMore from the FT GroupMarkets data delayed by at least 15',
#  'minutes. © THE FINANCIAL TIMES LTD 2024. FT and ‘Financial Times’ are',
#  'trademarks of The Financial Times Ltd.The Financial Times and its',
#  'journalism are subject to a self-regulation regime under the FT',
#  'Editorial Code of Practice.Close side navigation',
#  'menuEdition:InternationalUKSearch the FTSearchSubscribe for full',
#  'accessTop sectionsHomeWorldShow more WorldMiddle East warGlobal',
#  'EconomyUKUSChinaAfricaAsia PacificEmerging MarketsEuropeWar in',
#  'UkraineAmericasMiddle East & North AfricaUSShow more USUS',
#  'EconomyInvesting in AmericaUS CompaniesUS Politics & PolicyUS',
#  'Presidential Election 2024CompaniesShow more',
#  'CompaniesEnergyFinancialsHealthIndustrialsMediaProfessional',
#  'ServicesRetail & ConsumerTech SectorTelecomsTransportTechShow more',
#  'TechArtificial intelligenceSemiconductorsCyber SecuritySocial',
#  'MediaMarketsShow more MarketsAlphavilleMarkets DataCryptoCapital',
#  'MarketsCommoditiesCurrenciesEquitiesWealth ManagementMoral MoneyETF',
#  'HubFund ManagementTradingClimateOpinionShow more OpinionColumnistsThe',
#  'FT ViewThe Big ReadLexObituariesLettersLexWork & CareersShow more Work',
#  "& CareersBusiness School RankingsBusiness EducationEurope's Start-Up",
#  'HubsEntrepreneurshipRecruitmentBusiness BooksBusiness TravelWorking',
#  'ItLife & ArtsShow more Life & ArtsArtsBooksFood & DrinkFT',
#  'MagazineHouse & HomeStyleTravelFT GlobetrotterPersonal FinanceShow',
#  'more Personal FinanceProperty & MortgagesInvestmentsPensionsTaxBanking',
#  '& SavingsAdvice & CommentNext ActHTSISpecial ReportsFT',
#  'recommendsAlphavilleFT EditLunch with the FTFT',
#  'Globetrotter#techAsiaMoral MoneyVisual and data',
#  'journalismNewslettersVideoPodcastsNews feedFT SchoolsFT Live EventsFT',
#  'ForumsBoard Director ProgrammemyFTPortfolioFT Digital',
#  'EditionCrosswordOur AppsHelp CentreSubscribeSign In Personal Finance',
#  'News: Latest Financial News, Investment Tips, Personal Finance Updates',
#  'Explore Sign in e-paper Subscribe Sign In Wednesday, 20 November 2024',
#  'Stocks Mutual Funds News Home News Markets Premium Money Mutual Fund',
#  'Personal Loan Companies Technology Web Stories In Charts Opinion',
#  'Videos All Companies Technology Markets Money MyMint Mutual Funds',
#  'Insurance Auto Industry Personal Finance Hello User Sign in Sign Out',
#  'My Account My Account Subscribe My Watchlist Newsletters Notifications',
#  'My Reads For You View Less - View More + Data Insights Market',
#  'Dashboard Bullion Gold Silver Fuel Petrol Diesel Commodities Gold',
#  'GoldM Aluminum Menthaoil Silver SilverMIC GoldPetal Natural Gas Copper',
#  'Zinc SilverM CrudeOil GoldGinuea Lead CryptoCurrencies View Less -',
#  "View More + Top Sections Today's News India News World News US News",
#  'Today Economy Money News Personal Finance Q&A Opinion Company Business',
#  'News IPO News Start-ups Company Results Top Company Leader Stock',
#  'Market News Stock Markets Commodity News Mark To Market IPO News Live',
#  'Blog personal loan personal loan emi calculator Personal Loan Interest',
#  'Rate Personal Loan Eligibility Business Loan Instant Loan Election',
#  'Results 2024 Assembly Elections 2024 Indian Industry Analysis Banking',
#  'News Infotech News Infrastructure Agriculture Manufacturing Energy',
#  'News Retail News Auto News Sports News Opinion Views Columns',
#  'Technology News Gadgets Tech Reviews App News Politics News Lounge',
#  'Sports News IPL 2025 IPL Points Table 2025 IPL 2025 Orange Cap IPL',
#  '2025 Purple Cap IPL Match Today | IPL 2024 Schedule Education News',
#  'Today View Less - View More + Premium Offerings e-paper WSJ Economist',
#  'MyMint Mint Premium View Less - View More + Tools and Calculators IFSC',
#  'Code Finder Income Tax Calculator SIP Calculator EMI Calculator Home',
#  'Loan EMI Calculator Car Loan EMI NPS Calculator View Less - View More',
#  '+ MultiMedia Collections Videos WebStories Photo Gallery Podcasts View',
#  'Less - View More + More From Mint Mint Genie Mint Lounge Explore Mint',
#  'About Us Print Subscription Mint Authors Terms of Use Disclaimer Mint',
#  'Code Code of ethics Cookie Policy Privacy Policy Subscriber - Terms of',
#  'Use SITEMAP Contact Us Mint Apps View Less - View More + Copyright ©',
#  'HT Digital Streams Limited All Rights Reserved. OPEN IN APP Gainers &',
#  'Losers Top Gainers Top Losers Mahindra & Mahindra share price',
#  '2,948.103.55% Tech Mahindra share price 1,699.202.28% HDFC Bank share',
#  'price 1,742.252.21% Sun Pharmaceutical Industries share price',
#  '1,775.201.60% Wipro share price 561.651.56% Reliance Industries share',
#  'price 1,241.30-1.53% State Bank Of India share price 802.00-1.44% Tata',
#  'Steel share price 139.45-1.31% Bajaj Finserv share price',
#  '1,596.05-1.21% Maruti Suzuki India share price 10,968.45-1.13% Active',
#  'Stocks Tue Nov 19 2024 15:59:51 Tata Steel share price 139.45 -1.31%',
#  'Tata Motors share price 783.40 1.47% NTPC share price 366.10 -0.16%',
#  'Kotak Mahindra Bank share price 1,726.65 0.24% Wipro share price',
#  '561.65 1.56% Business News/ Money Money News home Can a private trust',
#  'benefit a differently abled child? Premium Trusts can be customised to',
#  'align with a specially abled child’s unique requirements and evolving',
#  'circumstances. (iStockimage) 2 min read . 19 Nov 2024 Aditya',
#  'Chopra,Moxy Shah Establishing a private trust for a differently abled',
#  'child allows parents to control asset management and distribution,',
#  'ensuring funds are used for specific needs like medical care and',
#  'education, while protecting resources from mismanagement. Share Via',
#  'Read Full Story Listen to this article Close Premium MintGenie Credit',
#  'card: Can you be sued for not paying your credit card bill? 2 min read',
#  '. 19 Nov 2024 Share Via Premium CEO is usually the lowest-paid',
#  "employee of a start-up: Greptile's Daksh Gupta 3 min read . 19 Nov",
#  '2024 Share Via Premium Plan to retain your Employees’ Provident Fund',
#  'balance after retiring? Read this. 1 min read . 19 Nov 2024 Share Via',
#  'Premium Taxman knows about your foreign assets and is giving you a',
#  'chance to revise ITR 1 min read . 19 Nov 2024 Share Via Premium',
#  'MintGenie How does your credit score affect your personal loan',
#  'application? 5 min read . 19 Nov 2024 Share Via Premium Secured vs.',
#  'Unsecured Personal Loans: Which one should you choose? 3 min read . 19',
#  'Nov 2024 Share Via Premium MintGenie Small Savings Schemes: 8',
#  'financial instruments offer interest up to 8.2% 2 min read . 19 Nov',
#  '2024 Share Via Premium How to apply for a personal loan? A step-by-',
#  'step guide 4 min read . 19 Nov 2024 Share Via Premium What is a credit',
#  'score? All you need to know 4 min read . 19 Nov 2024 Share Via Premium',
#  'Personal loan interest rates: Fixed vs. floating rates 2 min read . 19',
#  'Nov 2024 Share Via Premium What are the different types of personal',
#  'loans available in India? 3 min read . 19 Nov 2024 Share Via Premium',
#  'Mind over market: 7 habits of investors who thrive during corrections',
#  '1 min read . 19 Nov 2024 Share Via Premium Are small cap funds still',
#  'risky for investors? Latest stress test reveals THIS.. 2 min read . 19',
#  'Nov 2024 Share Via Premium Are you eligible for a personal loan? Find',
#  'out what you need 3 min read . 19 Nov 2024 Share Via Premium What is a',
#  'personal loan? A comprehensive guide for first-time borrowers 3 min',
#  'read . 19 Nov 2024 Share Via Premium MintGenie Best Mutual Funds:',
#  'These value schemes gave over 18% CAGR return in past 3 years 2 min',
#  'read . 19 Nov 2024 Share Via Premium Do I need to bring the money I',
#  'earned abroad when returning to India? 1 min read . 18 Nov 2024 Share',
#  'Via Premium Best small business credit card rewards: Earn points,',
#  'cashback, and more 3 min read . 18 Nov 2024 Share Via Premium What are',
#  'the consumer protection laws that apply to credit cards? 3 min read .',
#  '18 Nov 2024 Share Via Recommended For You Connect with us: trending',
#  'stories NTPC Green Energy IPO NTPC Green Energy IPO GMP Blue Sky',
#  'Social media Livemint Hindi Election Commission of India Zee',
#  'Entertainment share price Maharashtra Elections 2024 Upcoming IPO 2024',
#  'Bank Holidays in Uttar Pradesh Bank Holidays in Gujarat Bank Holidays',
#  'in Delhi Bank Holidays in September Bank Holidays in Jammu And Kashmir',
#  'Instant Personal Loan Check Credit Score Online Business Loan Personal',
#  'Loan Interest Rate Personal Loan Eligibility Personal Loan EMI',
#  'Calculator Gold Rate in Delhi Gold Rate in Bangalore Gold Rate in',
#  'Chennai Gold Rate in Hyderabad Gold Rate in Mumbai Credit Card',
#  'Business Radio - FAB Play Assembly Election Results Data Pages',
#  'Quarterly Results Calendar Petrol Prices Diesel Prices MCX Gold Price',
#  'Election Results 2024 Assembly Election Results 2024 MCX Silver Price',
#  'Gold Price Silver Price NSE TOP Gainers NSE TOP Losers BSE TOP Gainers',
#  'BSE TOP Losers Bank Holidays 2024 Upcoming IPO 2024 BSE Q3 Results',
#  '2023 Income Tax Calculator popular stocks JSW INFRASTRUCTURE share',
#  'price R R KABEL share price CONCORD BIOTECH share price IDBI Bank',
#  'share price Yes Bank share price Adani Power share price HUL share',
#  'price Indian Oil share price Vedanta share price Jio Financial',
#  'Services share price Paytm share price Punjab National Bank share',
#  'price Canara Bank share price Adani Green Energy share price Indian',
#  'Railway Finance Corporation share price Suzlon Energy share price',
#  'IREDA share price Vodafone Idea share price Orient Technologies share',
#  'price Premier Energies share price Bajaj Housing Finance Share Price',
#  'Garuda Construction And Engineer share price Hyundai Motor India share',
#  'price latest stories Jaguar reveals new logo and branding, but',
#  'netizens complain ‘go back…’ Bank Holiday today: Are banks closed on',
#  'Nov 20 for Maharashtra assembly polls Tech News Today Live Updates on',
#  'November 20, 2024: Meet Artemis: The robot set to dribble past Messi',
#  'and dominate the World Cup | WATCH Meet Artemis: The robot set to',
#  'dribble past Messi and dominate the World Cup Trending News Today Live',
#  "Updates: AR Rahman's emotional note after wife Saira Banu confirms",
#  "separation: ‘Pieces may not find their place again’ AR Rahman's",
#  'emotional note after wife Saira Banu confirms separation 5 benefits of',
#  'napping for productivity and health 5 easy ways to use orange peels in',
#  'everyday life Companies News Today Live Updates on November 20, 2024:',
#  'Jaguar reveals new logo and branding, but netizens complain ‘go',
#  'back…’, Elon Musk asks ‘do you sell cars?’ Adani to Invest $2 billion',
#  'to set up International Convention Centre Nifty 50 Companies ADANI',
#  'ENTERPRISES share price ADANI PORTS share price APOLLO HOSPITALS share',
#  'price ASIAN PAINTS share price AXIS BANK share price BAJAJ AUTO share',
#  'price BAJAJ FINANCE share price BAJAJ FINSERVE share price BPCL share',
#  'price BHARTI AIRTEL share price BRITANNIA share price CIPLA share',
#  'price COAL INDIA share price DIVIS LABORATORIES share price DR REDDYS',
#  'LABORATORIES share price EICHER MOTORS share price GRASIM INDUSTRIES',
#  'share price HCL TECHNOLOGIES share price HDFC BANK share price HDFC',
#  'LIFE share price HERO MOTOCORP share price HINDALCO INDUSTRIES share',
#  'price HINDUSTAN UNILEVER share price ICICI BANK share price ITC share',
#  'price INDUSIND BANK share price INFOSYS share price JSW STEEL share',
#  'price KOTAK BANK share price LARSEN & TOURBO share price MAHINDRA &',
#  'MAHINDRA share price MARUTI SUZUKI share price NTPC share price NESTLE',
#  'INDIA share price ONGC share price POWER GRID share price RELIANCE',
#  'INDUSTRIES share price SBI LIFE share price SBI share price SUN PHARMA',
#  'share price TCS share price TATA MOTORS share price TATA STEEL share',
#  'price TATA CONSUMER share price TECH MAHINDRA share price TITAN share',
#  'price UPL share price ULTRATECH CEMENT share price WIPRO share price',
#  'DOWNLOAD APP Download the Mint app and read premium stories About Us',
#  'Contact Us Terms Of Use Privacy Policy RSS Copyright © 2023 HT Digital',
#  'Streams Ltd All Right Reserved No NetworkServer IssueInternet Not',
#  'AvailableWait for it…Log in to our website to save your bookmarks.',
#  "It'll just take a moment.Yes, Continue You are just one step away from",
#  'creating your watchlist!Login Now Wait for it…Oops! Looks like you',
#  'have exceeded the limit to bookmark the image. Remove some to bookmark',
#  'this image. Your session has expired, please login again.Yes, Continue',
#  'Congratulations!You are now subscribed to our newsletters. In case you',
#  'can’t find any email from our side, please check the spam folder. × ×',
#  'Get alerts on WhatsApp Gift an article Set Preferences My Reads',
#  'Watchlist Feedback Redeem a Gift Card Logout Subscribe to continue',
#  'This is a subscriber only feature Subscribe Now to get daily updates',
#  'on WhatsApp Market News: Share Market Today, NIFTY, BSE/NSE LIVE,',
#  'Sensex Today, Latest Share Market News Live UpdatesSubscribeSign',
#  'inView Market DashboardHomeLatest NewsMarketsMarket NewsMark to',
#  'MarketCommoditiesLive BlogsCryptocurrencyIPOStock MarketsMarket',
#  'DataStock PagesIndex pagesBullionGold',
#  'SilverFuelPetrolDieselNewsIndiaWorldWSJEconomistNewsUS NewsPremium',
#  'e-paperGlobal Partners WSJEconomistMint SpecialsMint ExplainersMark to',
#  'MarketLong StoryMint',
#  'PrimerSnapviewSectionsCompaniesTechnologyMarketsMoneyMutual',
#  'FundsInsuranceAutoIndustryPersonal FinanceCompaniesStart-upsCompany',
#  'ResultsPeopleMoneyPersonal FinanceInsurance Ask Mint MoneyMutual',
#  'FundsMyMintAssembly Elections 2024Personal LoanTechnologyGadgetsTech',
#  'ReviewsApp News5G TechFoldable SmartphonesIn ChartsMoreElection',
#  'Results 2024OpinionAuto NewsSportsIPL 2025IPL 2025 Purple CapIPL 2025',
#  'Orange CapIPL 2025 Points TableEducationTools IFSC Code FinderIncome',
#  'Tax CalculatorMint LoungeMintGenie Multi-MediaVideosWebStories Photo',
#  'GalleryPodcastsExplore MintAbout usPrint subscriptionMint',
#  'AuthorsPrivacy PolicyTerms of UseDisclaimerMint codeCookie PolicyCode',
#  'of ethicsSubscriber terms of useSitemapContact Us Hello UserSign',
#  'inSign OutMy AccountSubscribeMy WatchlistNewslettersNotificationsMy',
#  'ReadsFor YouView Less -View More +Data InsightsMarket DashboardBullion',
#  'GoldSilverFuelPetrolDieselCommoditiesGoldGoldMAluminumMenthaoilSilverS',
#  'ilverMICGoldPetalNatural',
#  'GasCopperZincSilverMCrudeOilGoldGinueaLeadCryptoCurrenciesView Less',
#  "-View More +Top SectionsToday's NewsIndia NewsWorld NewsUS News",
#  'TodayEconomyMoney NewsPersonal FinanceQ&AOpinionCompany Business',
#  'NewsIPO NewsStart-upsCompany ResultsTop Company LeaderStock Market',
#  'NewsStock MarketsCommodity NewsMark To MarketIPO NewsLive Blogpersonal',
#  'loanpersonal loan emi calculatorPersonal Loan Interest RatePersonal',
#  'Loan EligibilityBusiness LoanInstant LoanElection Results 2024Assembly',
#  'Elections 2024Indian Industry AnalysisBanking NewsInfotech',
#  'NewsInfrastructureAgricultureManufacturingEnergy NewsRetail NewsAuto',
#  'NewsSports NewsOpinionViewsColumnsTechnology NewsGadgetsTech',
#  'ReviewsApp NewsPolitics NewsLoungeBusiness of LifeSports NewsIPL 2025',
#  'IPL Points Table 2025IPL 2025 Orange CapIPL 2025 Purple CapIPL Match',
#  'Today | IPL 2024 Schedule Education News TodayView Less -View More',
#  '+Premium Offeringse-paperWSJEconomistMyMintMint PremiumView Less -View',
#  'More +Tools and CalculatorsIFSC Code FinderIncome Tax CalculatorSIP',
#  'CalculatorEMI CalculatorHome Loan EMI CalculatorCar Loan EMINPS',
#  'CalculatorView Less -View More +MultiMedia',
#  'CollectionsVideosWebStoriesPhoto GalleryPodcastsView Less -View More',
#  '+More From MintMint GenieMint LoungeView Less -Explore MintAbout',
#  'UsPrint SubscriptionMint AuthorsTerms of UseDisclaimerMint CodeCode of',
#  'ethicsCookie PolicyPrivacy PolicySubscriber - Terms of',
#  'UseSITEMAPContact UsMint AppsView Less -View More +Copyright © HT',
#  'Digital Streams Limited All Rights Reserved.HomeMarketsNifty- -Sensex-',
#  '-NSENSEBSEView MoreIndia VIX15.66 (+3.26%)NIFTY 10024,374.70',
#  '(+0.30%)NIFTY 5023,518.50 (+0.28%)NIFTY LargeMidCap 25015,340.70',
#  '(+0.63%)S&P BSE 10024,852.21 (+0.31%)S&P BSE 20010,815.62 (+0.37%)S&P',
#  'BSE 50034,650.83 (+0.45%)S&P BSE Bankex57,627.04 (+0.39%)Gold Price₹',
#  '76,493 (10 gm)0View DetailsSilver Price₹ 92,500 (1 kg)0View',
#  'DetailsLast Updated: (Note: NSE feeds are 15 mins delayed)AllMarket',
#  'DashboardMark To MarketStock Market NewsIPOCommoditiesMutual',
#  'FundsMarkets PremiumCompany NewsMarket VideosMarkets NewsIs Indian',
#  'stock market closed today for the Maharashtra Assembly Election?Stock',
#  'market holiday: To check whether the Indian stock market is open',
#  'tomorrow or not, one can find on the BSE website. Read more to know',
#  'tomorrow’s trading holiday details:1 min read06:43 AM ISTThe bravado',
#  'of retail investors: Buying the dip or skating on thin ice?4 min',
#  'read06:00 AM ISTGold prices surge by ₹600 to ₹78,050 amid strong',
#  'global trends; silver rises1 min read19 Nov 2024Sebi seeks to double',
#  'minimum subscription for SME IPOs to protect investors1 min read19 Nov',
#  '2024Aegis Vopak Terminals files draft papers with SEBI for ₹3,500',
#  'crore IPO1 min read19 Nov 2024Markets DashboardView MoreTop GainersTop',
#  'LosersICICI Direct Stock PicksMost Active Volume52 Week High52 Week',
#  'LowSTOCKSPRICECHANGE%CHANGEMtar Technologies1,746.65132.458.21V-Guard',
#  'Industries426.9530.607.72Apar Industries9,483.80668.107.58Craftsman',
#  'Automation4,978.00321.256.90Triveni Turbines687.1040.956.34To View All',
#  'Top Gainers Click HereSTOCKSPRICECHANGE%CHANGEMtar',
#  'Technologies1,746.65132.458.21V-Guard Industries426.9530.607.72Apar',
#  'Industries9,483.80668.107.58Craftsman',
#  'Automation4,978.00321.256.90Triveni',
#  'Turbines687.1040.956.34STOCKSPRICECHANGE%CHANGEMtar',
#  'Technologies1,746.65132.458.21V-Guard Industries426.9530.607.72Apar',
#  'Industries9,483.80668.107.58Craftsman',
#  'Automation4,978.00321.256.90Triveni',
#  'Turbines687.1040.956.34STOCKSPRICECHANGE%CHANGEMtar',
#  'Technologies1,746.65132.458.21V-Guard Industries426.9530.607.72Apar',
#  'Industries9,483.80668.107.58Craftsman',
#  'Automation4,978.00321.256.90Triveni',
#  'Turbines687.1040.956.34STOCKSPRICECHANGE%CHANGEMtar',
#  'Technologies1,746.65132.458.21V-Guard Industries426.9530.607.72Apar',
#  'Industries9,483.80668.107.58Craftsman',
#  'Automation4,978.00321.256.90Triveni',
#  'Turbines687.1040.956.34STOCKSPRICECHANGE%CHANGEMtar',
#  'Technologies1,746.65132.458.21V-Guard Industries426.9530.607.72Apar',
#  'Industries9,483.80668.107.58Craftsman',
#  'Automation4,978.00321.256.90Triveni Turbines687.1040.956.34More From',
#  'Market DashboardTrending StocksMahindra & Mahindra2,948.95 3.58%Tech',
#  'Mahindra1,699.65 2.34%HDFC Bank1,742.25 2.18%SBI Life Insurance',
#  'Company1,522.90 -2.54%Hindalco Industries640.00 -1.70%Reliance',
#  'Industries1,241.65 -1.51%AdvertisementAdvertisementMarket',
#  'HighlightsView More19 Nov 202419 Nov 202419 Nov 202419 Nov 202419 Nov',
#  '202419 Nov 202419 Nov 202419 Nov 202419 Nov 202419 Nov 2024Create',
#  'WatchlistUnlock curated news and stock insights for your favorite',
#  'stocksCreate NowNewslettersView MoreMark to Market View MoreAnalysis',
#  "of India's top companiesApollo Tyres has to cover a lot of ground to",
#  'reverse under-performance2 min read19 Nov 2024Indraprastha Gas and',
#  'Mahanagar Gas face perils of policy controls1 min read19 Nov',
#  '2024Nykaa’s beauty business growth is a highlight, but margin is a',
#  'sore spot1 min read18 Nov 2024Kalyan Jewellers is shining, but the',
#  'valuation is pricey1 min read18 Nov 2024Hero MotoCorp’s ride may be',
#  'easy3 min read18 Nov 2024ONGC looks to cash in on gas pricing tweak,',
#  'KG basin ramp-up1 min read14 Nov 2024Tata Chemicals’ Europe',
#  'restructuring helps, but dull soda ash market a worry1 min read14 Nov',
#  '2024More From Mark to MarketStock Market NewsView MoreStock Market',
#  'News Today Live Updates on November 20, 2024 : The bravado of retail',
#  'investors: Buying the dip or skating on thin ice?Stock Market News',
#  'Today Live Updates on November 20, 2024: Explore comprehensive',
#  'coverage of the stock market, with updates on key indices, stock',
#  'performance, and financial news. Track the biggest market moves and',
#  'discover how economic indicators, corporate earnings, and geopolitical',
#  'events impact investments worldwide1 min read06:00 AM ISTThe bravado',
#  'of retail investors: Buying the dip or skating on thin ice?4 min',
#  'read06:00 AM ISTMiami Developer Says Real Estate Market Needs Rate',
#  'Cuts ‘Badly’2 min read19 Nov 2024Oil Swings as Russia-Ukraine War,',
#  'Iran Agreement Roil Market2 min read19 Nov 2024Sebi seeks to double',
#  'minimum subscription for SME IPOs to protect investors1 min read19 Nov',
#  '2024Wall Street today: US stocks slip as investors rush to safe-haven',
#  'assets1 min read19 Nov 2024How Maharashtra polls could impact Indian',
#  'stock market. Experts weigh in1 min read19 Nov 2024More From Stock',
#  'Market NewsIPOView MoreAegis Vopak Terminals IPO: Storage tank',
#  'operator files draft papers with SEBI for ₹3,500 crore public',
#  'issueAegis Vopak Terminals Limited aims to raise ₹3,500 crore from a',
#  'fresh issue of equity shares into the Indian stock market. The company',
#  'is a joint venture between the promoters, Aegis Logistics, and the',
#  'Dutch tank storage firm subsidiary, Vopak India BV. 1 min read19 Nov',
#  '2024NTPC Green Energy IPO subscribed 33% on Day 1; Check GMP, other',
#  'details1 min read19 Nov 2024IPO watch: 9 issues listed in 2024 trade',
#  'below their prices; check full list1 min read19 Nov 2024Upcoming IPO:',
#  'Saatvik Green Energy files DRHP with SEBI for ₹1,150 crore offer1 min',
#  'read19 Nov 2024Onyx Biotec IPO allotment to be finalised soon: Latest',
#  'GMP, how to check status1 min read19 Nov 2024Zinka Logistics Solutions',
#  'IPO allotment date likely today. Steps to check status1 min read19 Nov',
#  '2024NTPC Green Energy IPO LIVE Updates: Issue subscribed 33% on Day',
#  '112 min read19 Nov 2024More From IPOCommoditiesView MoreGold prices',
#  'surge by ₹600 to ₹78,050 amid strong global trends; silver risesGold',
#  'prices on Tuesday, November 19, rose on strong global trends, reported',
#  'the news agency PTI. The international gold prices hit their highest',
#  'level since November 11.1 min read19 Nov 2024MCX',
#  'CommoditiesCOMMODITYPRICECHANGE%CHANGEGOLD Expiry: 26 Nov',
#  '20242,650.00504.0023.49SILVER Expiry: 26 Nov',
#  '2024160.00-49.50-23.63COPPER Expiry: 20 Nov 202410.57-10.64-50.17To',
#  'View All Commodities Click HereAdvertisementGold hits 1-week high on',
#  'safe-haven demand but down 4.4% in Nov. Time to buy?1 min read19 Nov',
#  '2024Gold and silver prices today on 19-11-2024: Check latest rates in',
#  'your city3 min read19 Nov 2024Gold price rises as dollar eases;',
#  'experts share key levels for MCX Gold rate2 min read19 Nov 2024More',
#  'From CommoditiesMutual FundsView MoreWhat should equity mutual fund',
#  'investors do amidst the market slump?Mutual Funds: The Nifty has',
#  'corrected 10% from its highs, causing concern among individual',
#  'investors, especially those who started investing in equity funds',
#  'post-Covid. Investors are advised to avoid panic selling, continue',
#  'SIPs, and reassess their risk profiles to navigate the downturn',
#  'effectively.4 min read18 Nov 2024Top Mutual',
#  'FundsEquityDebtHybridMutual FundsRatingAUM (CR)Quant Large Cap Fund',
#  'Regular GrowthNR2,415.88DSP Top 100 Equity Fund Regular Plan',
#  'Growth4,613.49WhiteOak Capital Large Cap Fund Regular',
#  'GrowthNR640.39Baroda BNP Paribas Large Cap Fund Regular Plan',
#  'Growth2,439.97What are arbitrage funds and how are they different from',
#  'largecap funds?9 min read18 Nov 2024Demat accounts reach 179 million;',
#  'new additions fall to 3.5 million in October3 min read17 Nov 2024What',
#  'are banking and financial service sectoral funds and its pros and',
#  'cons?8 min read12 Nov 2024More From Mutual FundsMarkets PremiumView',
#  'MoreThe bravado of retail investors: Buying the dip or skating on thin',
#  'ice?‘Buying the dip’ can be a lucrative strategy. But is it for retail',
#  'investors?4 min read06:00 AM ISTApollo Tyres has to cover a lot of',
#  'ground to reverse under-performance2 min read19 Nov 2024Indraprastha',
#  'Gas and Mahanagar Gas face perils of policy controls1 min read19 Nov',
#  '2024Your watchlist amid the market correction4 min read19 Nov 2024Why',
#  'these two derivative stocks look promising on charts4 min read19 Nov',
#  '2024Microfinance meltdown: Five stocks that could come out on top4 min',
#  'read19 Nov 2024Can these three breakout stocks help you beat the stock',
#  'market selloff?5 min read19 Nov 2024More From Markets PremiumCompany',
#  'NewsView MoreJaguar reveals new logo and branding, but netizens',
#  'complain ‘go back…’Jaguar plans to launch three new electric cars in',
#  '2026, focusing on reinventing its brand. A new logo and concept car',
#  'will debut at Miami Art Week, aiming to change perceptions of the',
#  'luxury brand as it transitions to fully electric models.1 min',
#  'read06:46 AM ISTResults CalendarSTOCKSRESULT DATEOrissa Minerals',
#  'Development20 Nov 2024Unistar Multimedia20 Nov 2024Omnipotent',
#  'Industries20 Nov 2024Brightcom Group20 Nov 2024Orient Tradelink20 Nov',
#  '2024To View All Results Calendar Click HereCompanies News Today Live',
#  'Updates on November 20, 2024: Jaguar reveals new logo and branding,',
#  'but netizens complain ‘go back…’, Elon Musk asks ‘do you sell cars?’2',
#  'min read06:40 AM ISTAdani to Invest $2 billion to set up International',
#  'Convention Centre3 min read06:13 AM ISTAirbus CEO Says Year-End',
#  'Delivery Goal Is ‘A Tough Journey’2 min read19 Nov 2024More From',
#  'Company NewsMarket VideosView MoreStock Market Crash: ₹50 Lakh Crore',
#  'Gone… But Signs Of Recovery Ahead?18 Nov 2024Niva Bupa Health',
#  'Insurance Shares List at a Premium on NSE & BSE14 Nov 2024NTPC Green',
#  'Energy IPO: Price Band, GMP & Financials | Should You Subscribe?13 Nov',
#  '2024Bitcoin Near $90K, M-Cap Surpasses Silver | Bitcoin Price Target |',
#  'Crypto News12 Nov 2024Bitcoin Breaks Above $81,000 For First Time Ever',
#  '| Trump’s Crypto Boost11 Nov 2024ACME Solar IPO Opens: Should You',
#  'Subscribe? | Price Band, GMP, & More7 Nov 2024Sagility India IPO',
#  'Opens: IPO Price Band, GMP & More | Should You Subscribe?5 Nov',
#  '2024More From VideosHomeMarketsPremiumInstant LoanMint ShortsDownload',
#  'AppDownload the Mint app and read premium storiesTrending StoriesNTPC',
#  'Green Energy IPO NTPC Green Energy IPO GMP Blue Sky Social media',
#  'Livemint Hindi Election Commission of India Zee Entertainment share',
#  'price Maharashtra Elections 2024 Upcoming IPO 2024 Bank Holidays in',
#  'Uttar Pradesh Bank Holidays in Gujarat Bank Holidays in Delhi Bank',
#  'Holidays in September Bank Holidays in Jammu And Kashmir Instant',
#  'Personal Loan Check Credit Score Online Business Loan Personal Loan',
#  'Interest Rate Personal Loan Eligibility Personal Loan EMI Calculator',
#  'Gold Rate in Delhi Gold Rate in Bangalore Gold Rate in Chennai Gold',
#  'Rate in Hyderabad Gold Rate in Mumbai Credit Card Business Radio - FAB',
#  'Play Assembly Election Results Popular StocksJSW INFRASTRUCTURE share',
#  'priceR R KABEL share priceCONCORD BIOTECH share priceIDBI Bank share',
#  'priceYes Bank share priceAdani Power share priceHUL share priceIndian',
#  'Oil share priceVedanta share priceJio Financial Services share',
#  'pricePaytm share pricePunjab National Bank share priceCanara Bank',
#  'share priceAdani Green Energy share priceIndian Railway Finance',
#  'Corporation share priceSuzlon Energy share priceIREDA share',
#  'priceVodafone Idea share priceOrient Technologies share pricePremier',
#  'Energies share priceBajaj Housing Finance Share PriceGaruda',
#  'Construction And Engineer share priceHyundai Motor India share',
#  'priceNifty 50 companiesADANI ENTERPRISES share priceADANI PORTS share',
#  'priceAPOLLO HOSPITALS share priceASIAN PAINTS share priceAXIS BANK',
#  'share priceBAJAJ AUTO share priceBAJAJ FINANCE share priceBAJAJ',
#  'FINSERVE share priceBPCL share priceBHARTI AIRTEL share priceBRITANNIA',
#  'share priceCIPLA share priceCOAL INDIA share priceDIVIS LABORATORIES',
#  'share priceDR REDDYS LABORATORIES share priceEICHER MOTORS share',
#  'priceGRASIM INDUSTRIES share priceHCL TECHNOLOGIES share priceHDFC',
#  'BANK share priceHDFC LIFE share priceHERO MOTOCORP share priceHINDALCO',
#  'INDUSTRIES share priceHINDUSTAN UNILEVER share priceICICI BANK share',
#  'priceITC share priceINDUSIND BANK share priceINFOSYS share priceJSW',
#  'STEEL share priceKOTAK BANK share priceLARSEN & TOURBO share',
#  'priceMAHINDRA & MAHINDRA share priceMARUTI SUZUKI share priceNTPC',
#  'share priceNESTLE INDIA share priceONGC share pricePOWER GRID share',
#  'priceRELIANCE INDUSTRIES share priceSBI LIFE share priceSBI share',
#  'priceSUN PHARMA share priceTCS share priceTATA MOTORS share priceTATA',
#  'STEEL share priceTATA CONSUMER share priceTECH MAHINDRA share',
#  'priceTITAN share priceUPL share priceULTRATECH CEMENT share priceWIPRO',
#  'share priceLatest StoriesJaguar reveals new logo and branding, but',
#  'netizens complain ‘go back…’, Elon Musk asks ‘do you sell cars?’Bank',
#  'Holiday today: Are banks closed on November 20 for Maharashtra',
#  'assembly elections 2024?Tech News Today Live Updates on November 20,',
#  '2024: Meet Artemis: The robot set to dribble past Messi and dominate',
#  'the World Cup | WATCHMeet Artemis: The robot set to dribble past Messi',
#  'and dominate the World Cup | WATCHTrending News Today Live Updates on',
#  'November 20, 2024 : AR Rahman’s emotional note after wife Saira Banu',
#  'confirms separation: ‘Pieces may not find their place again’AR',
#  'Rahman’s emotional note after wife Saira Banu confirms separation:',
#  '‘Pieces may not find their place again’5 benefits of napping for',
#  'productivity and health5 easy ways to use orange peels in everyday',
#  'lifeCompanies News Today Live Updates on November 20, 2024: Jaguar',
#  'reveals new logo and branding, but netizens complain ‘go back…’, Elon',
#  'Musk asks ‘do you sell cars?’Adani to Invest $2 billion to set up',
#  'International Convention Centre, takes on Jio',
#  'WorldSectionPremiumOpinionNewsMarketPoliticsCompaniesMoneySportsMutual',
#  'FundIndustryTechnologyToolsIFSC Code FinderIncome Tax CalculatorSIP',
#  'CalculatorHome Loan EMI CalculatorCar Loan EMINPS CalculatorData',
#  'PagesMarket DashboardIndicesTop GainerMutual FundsGold PriceSilver',
#  'PriceFuel PriceAbout UsMint AuthorsContact usTerms of UseCode of',
#  'EthicsPrivacy PolicyRSSCopyright © 2023 HT Digital Streams Ltd.All',
#  'Rights ReservedWait for it…Log in to our website to save your',
#  "bookmarks. It'll just take a moment.Yes, Continue"]

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate, PromptTemplate, ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


base_url = "http://localhost:11434"
model = "llama3.2:3b"

llm = ChatOllama(base_url=base_url,
                 model=model,
                 temperature=0.1,
                 num_predict=256
                 )

system = SystemMessagePromptTemplate.from_template("""
You are a helpful AI assistant who answer user question based on provide context.
""")

prompt = """Answer user question based on the provided context ONLY! if do not know the answer, just sai "I don't know".
### Context:
{context}

### Question:
{question}

### Answer:
"""

prompt = HumanMessagePromptTemplate.from_template(prompt)

messages = [system, prompt]
template = ChatPromptTemplate(messages)

qna_chain = template | llm | StrOutputParser()

# %%
def ask_llm(context, question):
    return qna_chain.invoke({'context':context, 'question':question})

# %%
answer = ask_llm(context[:10_000], 'extract crypto market news from the given text')
textwrap.wrap(answer)
# Out:
# ['Here are the crypto-related news extracted from the text:  1. Binance',
#  'boss hails crypto ‘golden age’ as Trump win fires up industry 2.',
#  'Bitcoin hits record above $75,000 as crypto industry celebrates Trump',
#  'win 3. Trump-aligned fund manager Strive jumps into bitcoin 4.',
#  '‘Satoshi Nakamoto’ says he also designed the Twitter logo 5. Crypto',
#  'exchanges turn to derivatives to lure cautious investors 6. Nigeria',
#  'drops money laundering charges against detained Binance executive 7.',
#  'Japan maintains cautious stance on crypto ETFs 8. House & HomeCrypto',
#  'has designs on real estate Buying blockchain-listed ‘slices’ of',
#  'properties is a nascent, niche and troubled market. 9. Donald Trump',
#  'has a new crypto venture. The industry is not impressed 10. EU markets',
#  'watchdog pushes for extra cyber defences in new crypto rules 11. FBI',
#  'creates its own crypto token to nab suspects in alleged fraud scheme',
#  '12. Crypto.com sues SEC after receiving legal threat from US regulator',
#  '13. Grayscale Ethereum Trust (ETH)Can a crypto ETF die of apathy? 14.',
#  '21Shares slashes fees on two flagship crypto ETPs 15. Caroline Ellison',
#  'gets 2-year prison sentence for FTX fraud 16.']

# %%
def chunk_text(text, chunk_size, overlap=100):
    chunks = []
    for i in range(0, len(text), chunk_size - overlap):
        chunks.append(text[i:i + chunk_size])
    return chunks

# %%
chunks = chunk_text(context, 10_000)

# %%
question = 'extract bitcoin news, personal financem loans and trusts from the given text'
chunk_summary = []
for chunk in chunks:
    response = ask_llm(chunk, question)
    chunk_summary.append(response)

# %%
chunk_summary
# Out:
# ['Here are the extracted news:\n\n**Bitcoin News:**\n\n1. Bitcoin hits record above $75,000 as crypto industry celebrates Trump win\n2. Binance boss hails crypto ‘golden age’ as Trump win fires up industry\n3. Bitcoin’s shift towards respectability should concern us all\n4. Examining MicroStrategy’s record-shattering $21bn A\n\n**Personal Finance:**\n\n1. Trump-aligned fund manager Strive jumps into bitcoin\n2. Wealth group doubles down on themes foremost in the ex-president’s financial community as election day nears\n\n**Loans and Trusts:**\n\n1. Grayscale Ethereum Trust (ETH)Can a crypto ETF die of apathy?\n2. Caroline Ellison gets 2-year prison sentence for FTX fraud',
#  'Here are the extracted topics:\n\n* Bitcoin News:\n\t+ "Trump victory tipped to break logjam of exotic US crypto ETF filings"\n\t+ "Binance boss hails crypto ‘golden age’ as Trump win fires up industry"\n\t+ "Endgame for Endgame?Trump vs Basel III"\n* Personal Finance:\n\t+ "No work phone? Companies tell staff to bring their own"\n\t+ "An interview with Yale’s Steven Kelly" (not directly related, but mentions investment)\n* Loans and Trusts:\n\t+ None found in the given text.',
#  'Here are the extracted information:\n\n**Bitcoin News**\n\n* None mentioned in the provided text.\n\n**Personal Finance**\n\n* Loans:\n\t+ Personal loan interest rates: Fixed vs. floating rates\n\t+ Secured vs. Unsecured Personal Loans: Which one should you choose?\n\t+ How to apply for a personal loan? A step-by-step guide\n\t+ What is a credit score? All you need to know\n\t+ Small Savings Schemes: 8 financial instruments offer interest up to 8.2%\n* Credit Score:\n\t+ How does your credit score affect your personal loan application?\n\t+ What is a credit score? All you need to know\n\n**Trusts**\n\n* Establishing a private trust for a differently abled child allows parents to control asset management and distribution, ensuring funds are used for specific needs like medical care and education, while protecting resources from mismanagement.\n* Can a private trust benefit a differently abled child?\n* Plan to retain your Employees’ Provident Fund balance after retiring? Read this. (This one is related to trusts as it mentions retaining PF balance in a trust)',
#  "Unfortunately, you didn't provide any text for me to extract information from. Please paste the text, and I'll be happy to help you with extracting Bitcoin news, personal finance, loans, and trusts.",
#  "There is no specific text provided to extract from. Please provide the text you would like me to work with, and I'll be happy to assist you in extracting Bitcoin news, personal finance, loans, and trusts.",
#  "I don't know."]
